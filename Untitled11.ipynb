# %% [markdown]
# <a href="https://colab.research.google.com/github/softwaremahasiswa349-debug/scrapping/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install apify-client pandas openpyxl -q

from apify_client import ApifyClient
import pandas as pd
from google.colab import files

# ── ✏️  EDIT THESE ──────────────────────────────────────────
APIFY_TOKEN  = "apify_api_QgqeP0nhSM1tGssufanCstEXLqTjbj3HOYN0"
SEARCH_TERMS = ["#dirtyvote2"]
MAX_ITEMS    = 5000
DATE_START   = "2025-10-20"
DATE_END     = "2025-10-27"
OUTPUT_FILE  = "dataset_pemilu.csv"
# ────────────────────────────────────────────────────────────

client = ApifyClient(APIFY_TOKEN)

search_with_dates = []
for term in SEARCH_TERMS:
    q = term
    if DATE_START:
        q += f" since:{DATE_START}"
    if DATE_END:
        q += f" until:{DATE_END}"
    search_with_dates.append(q)

input_data = {
    "searchTerms" : search_with_dates,
    "maxItems"    : MAX_ITEMS,
    "queryType"   : "Latest",
    "filter:nativeretweets"  : False,
    "include:nativeretweets" : False,
}

print("🚀 Mulai scraping...")
print(f"   Hashtag  : {SEARCH_TERMS}")
print(f"   Rentang  : {DATE_START} s/d {DATE_END or 'sekarang'}")
print(f"   Max item : {MAX_ITEMS:,}")

run  = client.actor("CJdippxWmn9uRfooo").call(run_input=input_data)
data = []

# ✅ FIXED: use .default_dataset_id attribute instead of run["defaultDatasetId"]
for item in client.dataset(run.default_dataset_id).iterate_items():
    text = item.get("text", "")
    data.append({
        "text"     : text,
        "date"     : item.get("createdAt", ""),
        "username" : item.get("author", {}).get("userName", ""),
        "likes"    : item.get("likeCount",   0),
        "retweets" : item.get("retweetCount", 0),
        "hashtags" : ", ".join(w for w in text.split() if w.startswith("#")),
    })

df = pd.DataFrame(data)

df["date"] = pd.to_datetime(df["date"], utc=True, format="mixed")
df["date"] = df["date"].dt.tz_convert("Asia/Jakarta")
df["date"] = df["date"].dt.strftime("%Y-%m-%d")

before = len(df)
df = df.drop_duplicates(subset=["text"])

if DATE_START:
    df = df[df["date"] >= DATE_START]
if DATE_END:
    df = df[df["date"] <= DATE_END]

df = df.sort_values("date", ascending=False).reset_index(drop=True)

print(f"\n✅ Total terkumpul  : {len(df):,} tweet")
print(f"📅 Rentang tanggal  : {df['date'].min()} s/d {df['date'].max()}")
print(f"🔁 Duplikat dihapus : {before - len(df)}")
print(f"👤 Unique user      : {df['username'].nunique():,}")
print(f"❤️  Total likes      : {df['likes'].sum():,}")

df.to_csv(OUTPUT_FILE, index=False)
print(f"\n💾 Tersimpan → {OUTPUT_FILE}")
files.download(OUTPUT_FILE)
# Out:
# 🚀 Mulai scraping...
#    Hashtag  : ['#dirtyvote2']
#    Rentang  : 2025-10-20 s/d 2025-10-27
#    Max item : 5,000
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> Status: RUNNING, Message:
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:10.662Z ACTOR: Pulling container image of build FsAg9tvxqxfok3E4f from registry.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:10.665Z ACTOR: Creating container.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:10.830Z ACTOR: Starting container.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:10.830Z ACTOR: Running under "LIMITED_PERMISSIONS".
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.209Z Actor is running on the Apify platform, `disable_browser_sandbox` was changed to True.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.214Z [apify] INFO  Initializing Actor ({"apify_sdk_version": "3.0.3", "apify_client_version": "2.5.1", "crawlee_version": "1.7.2", "python_version": "3.12.13", "os": "linux"})
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.380Z ACTOR_MAX_PAID_DATASET_ITEMS is : 6859
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.380Z actor_input is :
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.381Z {'searchTerms': ['#dirtyvote2 since:2025-10-20 until:2025-10-27'], 'maxItems': 5000, 'queryType': 'Latest', 'filter:nativeretweets': False, 'include:nativeretweets': False, 'filter:blue_verified': False, 'filter:replies': False, 'filter:quote': False, 'filter:has_engagement': False, 'min_retweets': 0, 'min_faves': 0, 'min_replies': 0, '-min_retweets': 0, '-min_faves': 0, '-min_replies': 0, 'filter:media': False, 'filter:twimg': False, 'filter:images': False, 'filter:videos': False, 'filter:native_video': False, 'filter:vine': False, 'filter:consumer_video': False, 'filter:pro_video': False, 'filter:spaces': False, 'filter:links': False, 'filter:mentions': False, 'filter:news': False, 'filter:safe': False, 'filter:hashtags': False}
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.381Z apify_token is *********,apify_user_id is 7qp29tcoebDFqEvC3,actor_id is CJdippxWmn9uRfooo,actor_run_id is 3V73w0XrjndYg8x1v
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.402Z [apify] ERROR Failed to get user info, status code: 404
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.403Z username is ,isPaying is -1
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.423Z build_query done ,query is :,tweet_ids is None. searchTerms is ['#dirtyvote2 since:2025-10-20 until:2025-10-27']
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:17.424Z searchTerms is not none.will search by searchTerms:['#dirtyvote2 since:2025-10-20 until:2025-10-27']
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:18.851Z entry_type is TimelineTimelineItem
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:18.901Z entry_type is TimelineTimelineItem
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:18.951Z entry_type is TimelineTimelineItem
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:19.023Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:19.052Z cursor_type is Top
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:19.052Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:19.102Z cursor_type is Bottom
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:20.706Z has_TimelineAddEntries_in_instructions or no cursor,will break.query is #dirtyvote2 since:2025-10-20 until:2025-10-27,cursor is DAADDAABCgABG3z3A8UaoLYKAAIbeszh3RtAaAAIAAIAAAACCAADAAAAAAgABAAAAAEKAAUct4Dg40AnEAoABhy3gODjP7HgAAA
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:20.706Z mock_tweets's len is 12
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:23.747Z log fail error
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> 2026-06-23T03:40:23.750Z [apify] INFO  Exiting Actor ({"exit_code": 0})
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:3V73w0XrjndYg8x1v] -> Status: SUCCEEDED, Message:
# ✅ Total terkumpul  : 3 tweet
# 📅 Rentang tanggal  : 2025-10-20 s/d 2025-10-22
# 🔁 Duplikat dihapus : 12
# 👤 Unique user      : 3
# ❤️  Total likes      : 30
#
# 💾 Tersimpan → dataset_pemilu.csv
