# %%
# !pip install apify-client pandas openpyxl -q

from apify_client import ApifyClient
import pandas as pd
from google.colab import files

# ── ✏️  EDIT THESE ──────────────────────────────────────────
APIFY_TOKEN  = "apify_api_QgqeP0nhSM1tGssufanCstEXLqTjbj3HOYN0"
SEARCH_TERMS = ["#kecuranganpemilu", "#pemilucurang", "#dirtyvote2"]
MAX_ITEMS    = 5000
DATE_START   = "2025-10-20"  # YYYY-MM-DD (inclusive)
DATE_END     = "2025-10-22"  # YYYY-MM-DD (inclusive), or None
OUTPUT_FILE  = "dataset_pemilu.csv"
# ────────────────────────────────────────────────────────────

client = ApifyClient(APIFY_TOKEN)

# Build query with date range if provided
search_with_dates = []
for term in SEARCH_TERMS:
    q = term
    if DATE_START:
        q += f" since:{DATE_START}"
    if DATE_END:
        q += f" until:{DATE_END}"
    search_with_dates.append(q)

input_data = {
    "searchTerms" : search_with_dates,
    "maxItems"    : MAX_ITEMS,
    "queryType"   : "Latest",
    "filter:nativeretweets"  : False,
    "include:nativeretweets" : False,
}

print("🚀 Mulai scraping...")
print(f"   Hashtag  : {SEARCH_TERMS}")
print(f"   Rentang  : {DATE_START} s/d {DATE_END or 'sekarang'}")
print(f"   Max item : {MAX_ITEMS:,}")

run  = client.actor("CJdippxWmn9uRfooo").call(run_input=input_data)
data = []

for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    text = item.get("text", "")
    data.append({
        "text"     : text,
        "date"     : item.get("createdAt", ""),
        "username" : item.get("author", {}).get("userName", ""),
        "likes"    : item.get("likeCount",   0),
        "retweets" : item.get("retweetCount", 0),
        "hashtags" : ", ".join(w for w in text.split() if w.startswith("#")),
    })

df = pd.DataFrame(data)

# ── Date cleanup ────────────────────────────────────────────
df["date"] = pd.to_datetime(df["date"], utc=True, format="mixed")
df["date"] = df["date"].dt.tz_convert("Asia/Jakarta")
df["date"] = df["date"].dt.strftime("%Y-%m-%d")

# ── Deduplicate ─────────────────────────────────────────────
before = len(df)
df = df.drop_duplicates(subset=["text"])

# ── Date filter (safety net in case API returns extras) ──────
if DATE_START:
    df = df[df["date"] >= DATE_START]
if DATE_END:
    df = df[df["date"] <= DATE_END]

# ── Sort newest-first ────────────────────────────────────────
df = df.sort_values("date", ascending=False).reset_index(drop=True)

# ── Report ───────────────────────────────────────────────────
print(f"\n✅ Total terkumpul  : {len(df):,} tweet")
print(f"📅 Rentang tanggal  : {df['date'].min()} s/d {df['date'].max()}")
print(f"🔁 Duplikat dihapus : {before - len(df)}")
print(f"👤 Unique user      : {df['username'].nunique():,}")
print(f"❤️  Total likes      : {df['likes'].sum():,}")

df.to_csv(OUTPUT_FILE, index=False)
print(f"\n💾 Tersimpan → {OUTPUT_FILE}")
files.download(OUTPUT_FILE)
# Out:
# 🚀 Mulai scraping...
#    Hashtag  : ['#kecuranganpemilu', '#pemilucurang', '#dirtyvote2']
#    Rentang  : 2025-10-20 s/d 2024-10-22
#    Max item : 5,000
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> Status: RUNNING, Message:
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:35.985Z ACTOR: Pulling container image of build FsAg9tvxqxfok3E4f from registry.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:35.994Z ACTOR: Creating container.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:36.043Z ACTOR: Starting container.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:36.044Z ACTOR: Running under "LIMITED_PERMISSIONS".
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.659Z Actor is running on the Apify platform, `disable_browser_sandbox` was changed to True.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.662Z [apify] INFO  Initializing Actor ({"apify_sdk_version": "3.0.3", "apify_client_version": "2.5.1", "crawlee_version": "1.7.2", "python_version": "3.12.13", "os": "linux"})
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.847Z ACTOR_MAX_PAID_DATASET_ITEMS is : 6914
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.848Z actor_input is :
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.848Z {'searchTerms': ['#kecuranganpemilu since:2025-10-20 until:2024-10-22', '#pemilucurang since:2025-10-20 until:2024-10-22', '#dirtyvote2 since:2025-10-20 until:2024-10-22'], 'maxItems': 5000, 'queryType': 'Latest', 'filter:nativeretweets': False, 'include:nativeretweets': False, 'filter:blue_verified': False, 'filter:replies': False, 'filter:quote': False, 'filter:has_engagement': False, 'min_retweets': 0, 'min_faves': 0, 'min_replies': 0, '-min_retweets': 0, '-min_faves': 0, '-min_replies': 0, 'filter:media': False, 'filter:twimg': False, 'filter:images': False, 'filter:videos': False, 'filter:native_video': False, 'filter:vine': False, 'filter:consumer_video': False, 'filter:pro_video': False, 'filter:spaces': False, 'filter:links': False, 'filter:mentions': False, 'filter:news': False, 'filter:safe': False, 'filter:hashtags': False}
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.849Z apify_token is *********,apify_user_id is 7qp29tcoebDFqEvC3,actor_id is CJdippxWmn9uRfooo,actor_run_id is eezG4pw7oj3tZx9x5
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.873Z [apify] ERROR Failed to get user info, status code: 404
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.874Z username is ,isPaying is -1
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.888Z build_query done ,query is :,tweet_ids is None. searchTerms is ['#kecuranganpemilu since:2025-10-20 until:2024-10-22', '#pemilucurang since:2025-10-20 until:2024-10-22', '#dirtyvote2 since:2025-10-20 until:2024-10-22']
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:42.889Z searchTerms is not none.will search by searchTerms:['#kecuranganpemilu since:2025-10-20 until:2024-10-22', '#pemilucurang since:2025-10-20 until:2024-10-22', '#dirtyvote2 since:2025-10-20 until:2024-10-22']
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:44.277Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:44.327Z cursor_type is Top
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:44.327Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:44.377Z cursor_type is Bottom
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:44.378Z has_TimelineAddEntries_in_instructions or no cursor,will break.query is #kecuranganpemilu since:2025-10-20 until:2024-10-22,cursor is DAADDAABAAgAAgAAAAIIAAMAAAAACAAEAAAAAAoABRy3f5o5gCcQCgAGHLd_mjl_2PAAAA
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:45.758Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:45.807Z cursor_type is Top
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:45.808Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:45.858Z cursor_type is Bottom
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:45.858Z has_TimelineAddEntries_in_instructions or no cursor,will break.query is #pemilucurang since:2025-10-20 until:2024-10-22,cursor is DAADDAABAAgAAgAAAAIIAAMAAAAACAAEAAAAAAoABRy3f5uwQCcQCgAGHLd_m7A_2PAAAA
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:47.350Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:47.401Z cursor_type is Top
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:47.401Z entry_type is TimelineTimelineCursor
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:47.451Z cursor_type is Bottom
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:47.451Z has_TimelineAddEntries_in_instructions or no cursor,will break.query is #dirtyvote2 since:2025-10-20 until:2024-10-22,cursor is DAADDAABAAgAAgAAAAIIAAMAAAAACAAEAAAAAAoABRy3f508gCcQCgAGHLd_nTx_2PAAAA
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:47.452Z mock_tweets's len is 15
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:50.714Z log fail error
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> 2026-06-23T03:34:50.715Z [apify] INFO  Exiting Actor ({"exit_code": 0})
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:eezG4pw7oj3tZx9x5] -> Status: SUCCEEDED, Message:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1870/3434940272.py in <cell line: 0>()
#      42 data = []
#      43
# ---> 44 for item in client.dataset(run["defaultDatasetId"]).iterate_items():
#      45     text = item.get("text", "")
#      46     data.append({
#
# TypeError: 'Run' object is not subscriptable
